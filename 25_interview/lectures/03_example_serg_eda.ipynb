# %%
import pandas as pd

# %%
df = pd.read_excel("./ДатаСет.xls", header=4, usecols="B:AT")
df
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#       ÈíòåðíåòÒåëåôîí  ÁåçíàëÈÌ  Çàëîã  ÈçÌàãàçèíà  ÈíòåðíåòÌàã  \
# 0         79219340888         0      0           0            1
# 1         79154546945         0      0           0            1
# 2         79219698365         0      0           0            1
# 3         79600447320         0      0           0            1
# 4         79110007709         0      0           0            1
# ...               ...       ...    ...         ...          ...
# 2364      79037478174         0      0           0            1
# 2365      79051914962         0      0           0            1
# 2366      79112124069         0      0           0            1
# 2367      79032936575         0      0           0            1
# 2368      79658736127         0      0           0            1
#
#       ÈíòåðíåòÌàãÑòàòóñ  ÈíòåðíåòÎïëàòà  ÈíòåðíåòÎïëàòàÊÊ  Îïëàòà  Îòãðóçêà  \
# ...

# %%
df.isna().sum()
# Out:
# ÈíòåðíåòÒåëåôîí                      0
# ÁåçíàëÈÌ                             0
# Çàëîã                                0
# ÈçÌàãàçèíà                           0
# ÈíòåðíåòÌàã                          0
# ÈíòåðíåòÌàãÑòàòóñ                    0
# ÈíòåðíåòÎïëàòà                       0
# ÈíòåðíåòÎïëàòàÊÊ                     0
# Îïëàòà                               0
# Îòãðóçêà                             0
# ÎòïðàâëåíÔðàí÷àéçè                   0
# ÏðèçíàêÁåçÍÄÑ                        0
# ÐåçåðâÈÌ                             0
# ÑóïîâîéÍàáîð                         0
# ÌàãàçèííûéÑ÷åò                       0
# ÖåíàÌàãàçèíà                         0
# ÑòàòóñÏðîáëåìËîãèñòèêè               0
# ÄîñòaâêàÄîÄîìà                       0
# ÍàëîæÏëàòåæ                          0
# ÑòàòóñÊîíñòðóêòîðà                   0
# ÊóïèòÑåé÷àñ                          0
# ÈñïîëüçóåòÓäÑêëàä                    0
# Ïðåäîïëàòà                           0
# ÈíòåðñêîëÈÌ                          0
# ...

# %%
_ = df.hist(figsize=(25, 15))
