# %% [markdown]
# # Software architecture

# %% [markdown]
# ## Scope

# %% [markdown]
# ## Characteristics

# %% [markdown]
# ## Motivation

# %% [markdown]
# # References
#
# [Software architecture](https://en.wikipedia.org/wiki/Software_architecture)
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
