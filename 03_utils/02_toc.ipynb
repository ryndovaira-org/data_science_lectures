# %% [markdown]
# # Table of Contents (TOC)

# %% [markdown]
# ## Установка NodeJS с помощью Conda
#
# [Ссылка](https://anaconda.org/conda-forge/nodejs)

# %%
# !conda install -c conda-forge nodejs -y
# !conda install -c conda-forge/label/gcc7 nodejs -y
# !conda install -c conda-forge/label/cf201901 nodejs -y
# !conda install -c conda-forge/label/cf202003 nodejs -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  conda-forge
#     nodejs-6.13.1              |                0        11.9 MB  conda-forge
#     openssl-1.1.1t             |       h7f8727e_0         3.7 MB
#     ------------------------------------------------------------
#                                            Total:        16.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgcc             conda-forge/linux-64::libgcc-7.2.0-h69d50b8_2
#   nodejs             conda-forge/linux-64::nodejs-6.13.1-0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#   certifi            pkgs/main/linux-64::certifi-2022.6.15~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl                                 1.1.1q-h7f8727e_0 --> 1.1.1t-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# certifi-2022.12.7    | 147 KB    |                                       |   0%
# ca-certificates-2022 | 143 KB    |                                       |   0%
#
# nodejs-6.13.1        | 11.9 MB   |                                       |   0%
#
#
# openssl-1.1.1t       | 3.7 MB    |                                       |   0%
#
#
#
# libgcc-7.2.0         | 304 KB    |                                       |   0%
#
#
# openssl-1.1.1t       | 3.7 MB    | 1                                     |   0%
# certifi-2022.12.7    | 147 KB    | ####                                  |  11%
#
#
# openssl-1.1.1t       | 3.7 MB    | ###5                                  |  10%
#
# nodejs-6.13.1        | 11.9 MB   |                                       |   0%
#
#
# openssl-1.1.1t       | 3.7 MB    | ############3                         |  33%
# ca-certificates-2022 | 143 KB    | ##################################### | 100%
# ca-certificates-2022 | 143 KB    | ##################################### | 100%
#
#
#
# libgcc-7.2.0         | 304 KB    | #9                                    |   5%
#
#
# openssl-1.1.1t       | 3.7 MB    | ####################1                 |  54%
#
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
#
#
#
# libgcc-7.2.0         | 304 KB    | #########7                            |  26%
#
#
# openssl-1.1.1t       | 3.7 MB    | ###########################8          |  75%
#
# nodejs-6.13.1        | 11.9 MB   | 4                                     |   1%
#
#
# openssl-1.1.1t       | 3.7 MB    | ###################################5  |  96%
#
#
#
# libgcc-7.2.0         | 304 KB    | #################5                    |  47%
#
# nodejs-6.13.1        | 11.9 MB   | 8                                     |   2%
#
#
# openssl-1.1.1t       | 3.7 MB    | ##################################### | 100%
#
#
#
# libgcc-7.2.0         | 304 KB    | ##################################### | 100%
#
#
#
# libgcc-7.2.0         | 304 KB    | ##################################### | 100%
#
# nodejs-6.13.1        | 11.9 MB   | #4                                    |   4%
#
# nodejs-6.13.1        | 11.9 MB   | #9                                    |   5%
#
# nodejs-6.13.1        | 11.9 MB   | ##5                                   |   7%
#
# nodejs-6.13.1        | 11.9 MB   | ###6                                  |  10%
#
# nodejs-6.13.1        | 11.9 MB   | ####9                                 |  13%
#
# nodejs-6.13.1        | 11.9 MB   | ######4                               |  17%
#
# nodejs-6.13.1        | 11.9 MB   | ########7                             |  24%
#
# nodejs-6.13.1        | 11.9 MB   | ###########2                          |  30%
#
# nodejs-6.13.1        | 11.9 MB   | #############9                        |  38%
#
# nodejs-6.13.1        | 11.9 MB   | ################7                     |  45%
#
# nodejs-6.13.1        | 11.9 MB   | ###################4                  |  53%
#
# nodejs-6.13.1        | 11.9 MB   | ######################2               |  60%
#
# nodejs-6.13.1        | 11.9 MB   | ########################9             |  68%
#
# nodejs-6.13.1        | 11.9 MB   | ###########################7          |  75%
#
# nodejs-6.13.1        | 11.9 MB   | ##############################6       |  83%
#
# nodejs-6.13.1        | 11.9 MB   | #################################3    |  90%
#
# nodejs-6.13.1        | 11.9 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge/label/gcc7
#     certifi-2022.12.7          |  py310h06a4308_0         150 KB
#     nodejs-11.6.0              |    hf484d3e_1000        15.7 MB  conda-forge/label/gcc7
#     ------------------------------------------------------------
#                                            Total:        16.0 MB
#
# The following packages will be UPDATED:
#
#   nodejs                       conda-forge::nodejs-6.13.1-0 --> conda-forge/label/gcc7::nodejs-11.6.0-hf484d3e_1000
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> conda-forge/label/gcc7::ca-certificates-2018.10.15-ha4d7672_0
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/linux-64::certifi-2022.12.7-py310h06a4308_0
#
#
#
# Downloading and Extracting Packages
# nodejs-11.6.0        | 15.7 MB   |                                       |   0%
# certifi-2022.12.7    | 150 KB    |                                       |   0%
#
# ca-certificates-2018 | 135 KB    |                                       |   0%
# certifi-2022.12.7    | 150 KB    | ###9                                  |  11%
# certifi-2022.12.7    | 150 KB    | ##################################### | 100%
# nodejs-11.6.0        | 15.7 MB   |                                       |   0%
#
# nodejs-11.6.0        | 15.7 MB   |                                       |   0%
#
# nodejs-11.6.0        | 15.7 MB   | 1                                     |   0%
#
# ca-certificates-2018 | 135 KB    | ##############################7       |  83%
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2018.11.29 |       ha4d7672_0         143 KB  conda-forge/label/cf201901
#     nodejs-10.12.0             |       hfc679d8_0        15.5 MB  conda-forge/label/cf201901
#     ------------------------------------------------------------
#                                            Total:        15.6 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/label/gcc7::ca-certificat~ --> conda-forge/label/cf201901::ca-certificates-2018.11.29-ha4d7672_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   nodejs             conda-forge/label/gcc7::nodejs-11.6.0~ --> conda-forge/label/cf201901::nodejs-10.12.0-hfc679d8_0
#
#
#
# Downloading and Extracting Packages
# nodejs-10.12.0       | 15.5 MB   |                                       |   0%
# nodejs-10.12.0       | 15.5 MB   |                                       |   0%
# nodejs-10.12.0       | 15.5 MB   | 1                                     |   0%
# nodejs-10.12.0       | 15.5 MB   | 2                                     |   1%
# ca-certificates-2018 | 143 KB    | #############################         |  79%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge/label/cf202003
#     nodejs-12.4.0              |       he1b5a44_0        18.1 MB  conda-forge/label/cf202003
#     ------------------------------------------------------------
#                                            Total:        18.2 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/label/cf201901::ca-certif~ --> conda-forge/label/cf202003::ca-certificates-2019.11.28-hecc5488_0
#   nodejs             conda-forge/label/cf201901::nodejs-10~ --> conda-forge/label/cf202003::nodejs-12.4.0-he1b5a44_0
#
#
#
# Downloading and Extracting Packages
# nodejs-12.4.0        | 18.1 MB   |                                       |   0%
# ca-certificates-2019 | 145 KB    |                                       |   0%
# nodejs-12.4.0        | 18.1 MB   |                                       |   0%
# ca-certificates-2019 | 145 KB    | ################3                     |  44%
# nodejs-12.4.0        | 18.1 MB   | 1                                     |   0%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install tornado -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - tornado
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.01.10 |       h06a4308_0         120 KB
#     tornado-6.2                |  py310h5eee18b_0         602 KB
#     ------------------------------------------------------------
#                                            Total:         722 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/label/cf202003::ca-certif~ --> pkgs/main::ca-certificates-2023.01.10-h06a4308_0
#   tornado                               6.1-py310h7f8727e_0 --> 6.2-py310h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2023 | 120 KB    |                                       |   0%
# tornado-6.2          | 602 KB    |                                       |   0%
# ca-certificates-2023 | 120 KB    | ####9                                 |  13%
# ca-certificates-2023 | 120 KB    | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -c conda-forge jupyter_contrib_nbextensions -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/data-science-course-original
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyter_contrib_core-0.4.0 |     pyhd8ed1ab_0          18 KB  conda-forge
#     jupyter_contrib_nbextensions-0.7.0|     pyhd8ed1ab_0        20.4 MB  conda-forge
#     jupyter_highlight_selected_word-0.2.0|py310hff52083_1005          15 KB  conda-forge
#     jupyter_latex_envs-1.4.6   |  pyhd8ed1ab_1002         735 KB  conda-forge
#     jupyter_nbextensions_configurator-0.6.1|     pyhd8ed1ab_0         450 KB  conda-forge
#     libxslt-1.1.35             |       h4e12654_0         453 KB
#     lxml-4.9.1                 |  py310h1edc446_0         5.2 MB
#     pyyaml-6.0                 |  py310h5764c6d_4         178 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        27.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter_contrib_c~ conda-forge/noarch::jupyter_contrib_core-0.4.0-pyhd8ed1ab_0
#   jupyter_contrib_n~ conda-forge/noarch::jupyter_contrib_nbextensions-0.7.0-pyhd8ed1ab_0
#   jupyter_highlight~ conda-forge/linux-64::jupyter_highlight_selected_word-0.2.0-py310hff52083_1005
#   jupyter_latex_envs conda-forge/noarch::jupyter_latex_envs-1.4.6-pyhd8ed1ab_1002
#   jupyter_nbextensi~ conda-forge/noarch::jupyter_nbextensions_configurator-0.6.1-pyhd8ed1ab_0
#   libxslt            pkgs/main/linux-64::libxslt-1.1.35-h4e12654_0
#   lxml               pkgs/main/linux-64::lxml-4.9.1-py310h1edc446_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0-py310h5764c6d_4
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# jupyter_latex_envs-1 | 735 KB    |                                       |   0%
# lxml-4.9.1           | 5.2 MB    |                                       |   0%
#
# pyyaml-6.0           | 178 KB    |                                       |   0%
#
#
# jupyter_contrib_nbex | 20.4 MB   |                                       |   0%
#
#
#
# jupyter_nbextensions | 450 KB    |                                       |   0%
#
#
#
#
# yaml-0.2.5           | 87 KB     |                                       |   0%
#
#
#
#
#
# libxslt-1.1.35       | 453 KB    |                                       |   0%
#
#
#
#
#
#
# jupyter_contrib_core | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
# jupyter_highlight_se | 15 KB     |                                       |   0%
# jupyter_latex_envs-1 | 735 KB    | 8                                     |   2%
#
#
# jupyter_contrib_nbex | 20.4 MB   |                                       |   0%
#
# pyyaml-6.0           | 178 KB    | ###3                                  |   9%
# lxml-4.9.1           | 5.2 MB    | ##3                                   |   6%
#
#
# jupyter_contrib_nbex | 20.4 MB   | 3                                     |   1%
#
# jupyter_latex_envs-1 | 735 KB    | ###########2                          |  30%
#
# pyyaml-6.0           | 178 KB    | ##################################### | 100%
#
#
#
# jupyter_nbextensions | 450 KB    | #3                                    |   4%
# lxml-4.9.1           | 5.2 MB    | #####2                                |  14%
#
#
# jupyter_contrib_nbex | 20.4 MB   | 7                                     |   2%
#
#
#
#
# jupyter_latex_envs-1 | 735 KB    | #######################3              |  63%
#
#
#
#
# yaml-0.2.5           | 87 KB     | ##################################### | 100%
#
#
#
# jupyter_nbextensions | 450 KB    | ######5                               |  18%
# lxml-4.9.1           | 5.2 MB    | ########2                             |  22%
#
#
# jupyter_latex_envs-1 | 735 KB    | ####################################2 |  98%
# lxml-4.9.1           | 5.2 MB    | ##########6                           |  29%
#
#
#
# jupyter_nbextensions | 450 KB    | #############1                        |  36%
#
#
# jupyter_latex_envs-1 | 735 KB    | ##################################### | 100%
#
#
#
#
#
# libxslt-1.1.35       | 453 KB    | #3                                    |   4%
# lxml-4.9.1           | 5.2 MB    | ################5                     |  45%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #8                                    |   5%
#
#
#
# jupyter_nbextensions | 450 KB    | ###############################5      |  85%
#
#
#
#
#
# libxslt-1.1.35       | 453 KB    | ##########4                           |  28%
# lxml-4.9.1           | 5.2 MB    | ####################                  |  54%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##1                                   |   6%
#
#
#
#
#
#
# jupyter_contrib_core | 18 KB     | #################################5    |  91%
#
#
#
# jupyter_nbextensions | 450 KB    | ##################################### | 100%
#
#
#
#
#
#
# jupyter_contrib_core | 18 KB     | ##################################### | 100%
#
#
#
#
#
# libxslt-1.1.35       | 453 KB    | ############################7         |  78%
# lxml-4.9.1           | 5.2 MB    | #######################3              |  63%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
# jupyter_highlight_se | 15 KB     | ##################################### | 100%
# lxml-4.9.1           | 5.2 MB    | ###########################9          |  75%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###                                   |   8%
#
#
#
#
#
# libxslt-1.1.35       | 453 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# jupyter_highlight_se | 15 KB     | ##################################### | 100%
# lxml-4.9.1           | 5.2 MB    | ################################2     |  87%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###5                                  |  10%
# lxml-4.9.1           | 5.2 MB    | ####################################8 |  99%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ####                                  |  11%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ####5                                 |  12%
# lxml-4.9.1           | 5.2 MB    | ##################################### | 100%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####3                                |  14%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ######7                               |  18%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########3                             |  22%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #########9                            |  27%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###########5                          |  31%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #############1                        |  36%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##############7                       |  40%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ################3                     |  44%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##################                    |  49%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###################6                  |  53%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####################2                |  57%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ######################8               |  62%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########################4             |  66%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##########################            |  71%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###########################7          |  75%
#
#
# jupyter_contrib_nbex | 20.4 MB   | #############################3        |  79%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##############################9       |  84%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ################################5     |  88%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##################################1   |  92%
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: |
# \ Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/notebook/nbextensions.py", line 203, in install_nbextension_python
#     m, nbexts = _get_nbextension_metadata(module)
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/notebook/nbextensions.py", line 1107, in _get_nbextension_metadata
#     m = import_item(module)
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/traitlets/utils/importstring.py", line 38, in import_item
#     return __import__(parts[0])
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/latex_envs/__init__.py", line 3, in <module>
#     from . import latex_envs
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/latex_envs/latex_envs.py", line 20, in <module>
#     from nbconvert.exporters.exporter import Exporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/__init__.py", line 4, in <module>
#     from .exporters import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/__init__.py", line 3, in <module>
#     from .html import HTMLExporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/html.py", line 25, in <module>
#     from nbconvert.filters.highlight import Highlight2HTML
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/__init__.py", line 6, in <module>
#     from .markdown import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown.py", line 13, in <module>
#     from .markdown_mistune import markdown2html_mistune
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown_mistune.py", line 40, in <module>
#     class MathBlockGrammar(mistune.BlockGrammar):
# AttributeError: module 'mistune' has no attribute 'BlockGrammar'
#
# / Config option `kernel_spec_manager_class` not recognized by `EnableJupyterNbextensionsConfiguratorApp`.
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/ira/anaconda3/envs/data-science-course-original/etc/jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.6.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
#
# - Traceback (most recent call last):
#   File "/home/ira/anaconda3/envs/data-science-course-original/bin/jupyter-contrib-nbextension", line 6, in <module>
#     from jupyter_contrib_nbextensions.application import main
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/jupyter_contrib_nbextensions/application.py", line 13, in <module>
#     from jupyter_contrib_nbextensions.install import (
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/jupyter_contrib_nbextensions/install.py", line 16, in <module>
#     import jupyter_contrib_nbextensions.nbconvert_support
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/jupyter_contrib_nbextensions/nbconvert_support/__init__.py", line 5, in <module>
#     from .collapsible_headings import ExporterCollapsibleHeadings
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/jupyter_contrib_nbextensions/nbconvert_support/collapsible_headings.py", line 10, in <module>
#     from .exporter_inliner import ExporterInliner
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/jupyter_contrib_nbextensions/nbconvert_support/exporter_inliner.py", line 5, in <module>
#     from nbconvert.exporters.html import HTMLExporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/__init__.py", line 4, in <module>
#     from .exporters import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/__init__.py", line 3, in <module>
#     from .html import HTMLExporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/html.py", line 25, in <module>
#     from nbconvert.filters.highlight import Highlight2HTML
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/__init__.py", line 6, in <module>
#     from .markdown import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown.py", line 13, in <module>
#     from .markdown_mistune import markdown2html_mistune
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown_mistune.py", line 40, in <module>
#     class MathBlockGrammar(mistune.BlockGrammar):
# AttributeError: module 'mistune' has no attribute 'BlockGrammar'
#
# done
# ERROR conda.core.link:_execute(745): An error occurred while installing package 'conda-forge::jupyter_latex_envs-1.4.6-pyhd8ed1ab_1002'.
# Rolling back transaction: done
#
# LinkError: post-link script failed for package conda-forge::jupyter_latex_envs-1.4.6-pyhd8ed1ab_1002
# location of failed script: /home/ira/anaconda3/envs/data-science-course-original/bin/.jupyter_latex_envs-post-link.sh
# ==> script messages <==
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/notebook/nbextensions.py", line 203, in install_nbextension_python
#     m, nbexts = _get_nbextension_metadata(module)
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/notebook/nbextensions.py", line 1107, in _get_nbextension_metadata
#     m = import_item(module)
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/traitlets/utils/importstring.py", line 38, in import_item
#     return __import__(parts[0])
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/latex_envs/__init__.py", line 3, in <module>
#     from . import latex_envs
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/latex_envs/latex_envs.py", line 20, in <module>
#     from nbconvert.exporters.exporter import Exporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/__init__.py", line 4, in <module>
#     from .exporters import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/__init__.py", line 3, in <module>
#     from .html import HTMLExporter
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/exporters/html.py", line 25, in <module>
#     from nbconvert.filters.highlight import Highlight2HTML
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/__init__.py", line 6, in <module>
#     from .markdown import *
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown.py", line 13, in <module>
#     from .markdown_mistune import markdown2html_mistune
#   File "/home/ira/anaconda3/envs/data-science-course-original/lib/python3.10/site-packages/nbconvert/filters/markdown_mistune.py", line 40, in <module>
#     class MathBlockGrammar(mistune.BlockGrammar):
# AttributeError: module 'mistune' has no attribute 'BlockGrammar'
#
# ==> script output <==
# stdout:
# stderr:
# return code: 1
#
# ()

# %%
# !conda update conda --yes
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /home/ira/anaconda3/envs/data-science-course-original
#   package name: conda

# %% [markdown]
# ## Установка Table of Contents с помощью Conda
#
# [Ссылка](https://github.com/jupyterlab/jupyterlab-toc)

# %%
# !jupyter labextension install @jupyterlab/toc
# Out:
# Config option `kernel_spec_manager_class` not recognized by `InstallLabExtensionApp`.
# [W 2023-03-09 17:59:58.172 LabApp] Config option `kernel_spec_manager_class` not recognized by `LabApp`.
# An error occurred.
# ValueError: No version of @jupyterlab/toc could be found that is compatible with the current version of JupyterLab. However, it seems to support a new version of JupyterLab. Consider upgrading JupyterLab.
#
# Conflicting Dependencies:
# JupyterLab                  Extension      Package
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/apputils
# >=5.4.5 <5.5.0              >=5.6.1 <6.0.0 @jupyterlab/coreutils
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/docmanager
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/fileeditor
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/markdownviewer
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/notebook
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/rendermime
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/settingregistry
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/translation
# >=3.4.5 <3.5.0              >=3.6.1 <4.0.0 @jupyterlab/ui-components
# See the log file for details:  /tmp/jupyterlab-debug-wd_a5c9b.log
