# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

sys.path.append(os.path.abspath("../../"))
from utils.curve_analysis.ready_to_use_plots import *

# %% [markdown]
# # Power functions (Степенная функция)
#
# $f(x)=kx^{a}$

# %%
power_functions()

# %% [markdown]
# # Exponential function (Показательная функция)
#
# $f(x) = a^{x}$

# %%
exponential_functions()

# %% [markdown]
# # Logarithm functions (Логарифмическая функция)
#
# Логарифм числа $b$ по основанию $a$ определяется как показатель степени, в которую надо возвести основание $a$, чтобы получить число $b$. Обозначение: $\log _{a}b$.

# %%
logarithm_functions()

# %% [markdown]
# # Trigonometric functions (Тригонометрические функции)
#
# Тригонометрические функции — элементарные функции, которые исторически возникли при рассмотрении прямоугольных треугольников и выражали зависимости длин сторон этих треугольников от острых углов при гипотенузе (или, что равнозначно, зависимость хорд и высот от центрального угла дуги в круге).

# %%
trigonometric_functions()

# %% [markdown]
# # Identity function (Тождественное отображение)
#
# Функция, переводящая аргумент в себя.

# %%
identity_function()

# %% [markdown]
# # Sign function
#
# The **sign function** or **signum function** (from signum, Latin for "sign") is a function that returns the **sign of a real number**.
#
# $
# sgn(x) :=
# \begin{cases}
# -1 & \text{if } x < 0,\\
# 0 & \text{if } x = 0,\\
# 1 & \text{if} x > 0.
# \end{cases}
# $
#
# - Нечетная

# %%
sign_function()

# %% [markdown]
# # Absolute value / Modulus (Абсолютная величина / Модуль)
#
#
# $|x|={\begin{cases}x,&x>0,\\0,&x=0,\\-x,&\ x<0.\end{cases}}$

# %%
absolute_value()

# %% [markdown]
# # References
#
# [Степенная функция](https://ru.wikipedia.org/wiki/%D0%A1%D1%82%D0%B5%D0%BF%D0%B5%D0%BD%D0%BD%D0%B0%D1%8F_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F)
#
# [Показательная функция](https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D0%BA%D0%B0%D0%B7%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F)
#
# [Логарифмическая функция](https://ru.wikipedia.org/wiki/%D0%9B%D0%BE%D0%B3%D0%B0%D1%80%D0%B8%D1%84%D0%BC#%D0%9B%D0%BE%D0%B3%D0%B0%D1%80%D0%B8%D1%84%D0%BC%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F)
#
# [Тригонометрические функции](https://ru.wikipedia.org/wiki/%D0%A2%D1%80%D0%B8%D0%B3%D0%BE%D0%BD%D0%BE%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8)
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
