# %% [markdown]
# #

# %%
import pandas as pd

# %%
df = pd.read_csv('./part_10.csv')
df
# Out:
#             CLIENT_IP                                   CLIENT_USERAGENT  \
# 0       188.138.92.55                                                NaN
# 1      93.158.215.131  Mozilla/5.0 (Windows NT 6.3; WOW64; rv:45.0) G...
# 2      176.123.240.64  Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20...
# 3         73.78.81.63  Mozilla/5.0 (Windows NT 6.3; WOW64; rv:45.0) G...
# 4         66.102.9.44  Mozilla/5.0 (Linux; Android 4.4.2; GT-N7100 Bu...
# ...               ...                                                ...
# 57840  217.175.140.69         MICROSOFT_DEVICE_METADATA_RETRIEVAL_CLIENT
# 57841  109.206.151.20  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 57842     89.23.32.19  Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57...
# 57843   194.228.20.50  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 57844   188.43.52.163  curl/7.22.0 (i686-pc-linux-gnu) libcurl/7.22.0...
#
#       REQUEST_SIZE RESPONSE_CODE MATCHED_VARIABLE_SRC  \
# ...

# %%
df.describe()
# Out:
#              CLIENT_IP                                   CLIENT_USERAGENT  \
# count            57838                                              57517
# unique           24940                                               6992
# top     217.175.140.69  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# freq             11286                                               2117
#
#        REQUEST_SIZE RESPONSE_CODE MATCHED_VARIABLE_SRC MATCHED_VARIABLE_NAME  \
# count         57794         57770                57730                 53167
# unique         5758            60                   21                  3209
# top             259           200     REQUEST_GET_ARGS    REQUEST_GET_ARGS._
# freq            261         25771                20812                 11165
#
#                                    MATCHED_VARIABLE_VALUE  \
# count                                               57683
# unique                                              57611
# ...

# %%
list(df['MATCHED_VARIABLE_NAME'].unique())
# Out:
# [nan,
#  'url',
#  'REQUEST_GET_ARGS._',
#  'REQUEST_HEADERS.User-Agent',
#  'REQUEST_GET_ARGS.rid',
#  'REQUEST_COOKIES.LtpaToken2',
#  'REQUEST_COOKIES.user_id',
#  'REQUEST_HEADERS.If-Modified-Since',
#  'REQUEST_GET_ARGS.callback_uid',
#  'REQUEST_HEADERS.X-csrftoken',
#  '½\x9a×í\u05cd,Z\x85\x84\x11ÀTìÃ#w\x1f)\x01ۜs¸\x05Æ)݁ò_\x9aþ¿\xa0ÿ',
#  'REQUEST_GET_ARGS.r',
#  'REQUEST_COOKIES.User-cn',
#  'REQUEST_PATH',
#  'REQUEST_GET_ARGS.q',
#  'RESPONSE_HEADERS.Content-Type',
#  '%252525252526page%25252525253D2%252525252526page%25252525253D1%2525252526page%252525253D2%25252526page%2525253D2%252526page%25253D4%2526page%253D2%26page%3D1&page=2',
#  'id',
#  "X-Requested-With\\';\\'CSRF_TOKEN",
#  'order',
#  'REQUEST_COOKIES.rpx',
#  'REQUEST_POST_ARGS.__REQUESTDIGEST',
#  'REQUEST_COOKIES.KRTBCOOKIE_561',
#  'link',
#  'REQUEST_GET_ARGS.TS',
#  'REQUEST_COOKIES.icu',
#  'REQUEST_COOKIES._POSTED_INTERVIEW_STAT_ID',
#  'User-Agent',
#  'REQUEST_JSON.tags.uuid',
# ...

# %%
df[]unique
