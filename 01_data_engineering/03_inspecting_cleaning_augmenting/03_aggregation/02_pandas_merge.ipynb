# %%
import numpy as np

np.__version__
# Out:
# '1.20.2'

# %%
import pandas as pd

pd.__version__
# Out:
# '1.2.5'

# %%
df = pd.read_csv("../../../data_from_sergey/GAZP_210701_210713.csv")
df
# Out:
#      <TICKER>  <PER>    <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 0        GAZP      1  20210701  100100  281.88  282.57  281.88   282.47
# 1        GAZP      1  20210701  100200  282.42  282.86  282.32   282.74
# 2        GAZP      1  20210701  100300  282.74  283.00  282.50   282.77
# 3        GAZP      1  20210701  100400  282.64  282.90  282.50   282.59
# 4        GAZP      1  20210701  100500  282.67  282.69  282.11   282.25
# ...       ...    ...       ...     ...     ...     ...     ...      ...
# 6837     GAZP      1  20210713  155000  293.35  293.47  293.31   293.40
# 6838     GAZP      1  20210713  155100  293.40  293.41  293.22   293.33
# 6839     GAZP      1  20210713  155200  293.30  293.35  293.22   293.35
# 6840     GAZP      1  20210713  155300  293.35  293.42  293.28   293.31
# 6841     GAZP      1  20210713  155400  293.25  293.28  293.25   293.28
#
#        <VOL>
# 0     438510
# 1     487660
# 2     416910
# 3     264160
# 4     337050
# ...      ...
# ...

# %%
df2 = df.copy()

# df2['<TIME2>'] = df2['<TIME>']
# df2 = df2.drop(['<TIME>'], axis = 1)
# df2.rename(columns={"<TIME>": "<TIME2>"}, inplace=True)
df2
# Out:
#      <TICKER>  <PER>    <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 0        GAZP      1  20210701  100100  281.88  282.57  281.88   282.47
# 1        GAZP      1  20210701  100200  282.42  282.86  282.32   282.74
# 2        GAZP      1  20210701  100300  282.74  283.00  282.50   282.77
# 3        GAZP      1  20210701  100400  282.64  282.90  282.50   282.59
# 4        GAZP      1  20210701  100500  282.67  282.69  282.11   282.25
# ...       ...    ...       ...     ...     ...     ...     ...      ...
# 6837     GAZP      1  20210713  155000  293.35  293.47  293.31   293.40
# 6838     GAZP      1  20210713  155100  293.40  293.41  293.22   293.33
# 6839     GAZP      1  20210713  155200  293.30  293.35  293.22   293.35
# 6840     GAZP      1  20210713  155300  293.35  293.42  293.28   293.31
# 6841     GAZP      1  20210713  155400  293.25  293.28  293.25   293.28
#
#        <VOL>
# 0     438510
# 1     487660
# 2     416910
# 3     264160
# 4     337050
# ...      ...
# ...

# %%
# df2 = df2.set_index('<TIME2>')
df2 = df2.set_index("<TIME>")
df2
# Out:
#        <TICKER>  <PER>    <DATE>  <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>
# <TIME>
# 100100     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  282.42  282.86  282.32   282.74  487660
# 100300     GAZP      1  20210701  282.74  283.00  282.50   282.77  416910
# 100400     GAZP      1  20210701  282.64  282.90  282.50   282.59  264160
# 100500     GAZP      1  20210701  282.67  282.69  282.11   282.25  337050
# ...         ...    ...       ...     ...     ...     ...      ...     ...
# 155000     GAZP      1  20210713  293.35  293.47  293.31   293.40   20460
# 155100     GAZP      1  20210713  293.40  293.41  293.22   293.33  200960
# 155200     GAZP      1  20210713  293.30  293.35  293.22   293.35   24000
# 155300     GAZP      1  20210713  293.35  293.42  293.28   293.31   91710
# 155400     GAZP      1  20210713  293.25  293.28  293.25   293.28    3960
#
# [6842 rows x 8 columns]

# %%
df["<TIME>"] = df["<TIME>"] + 100
df = df.set_index("<TIME>")
df
# Out:
#        <TICKER>  <PER>    <DATE>  <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>
# <TIME>
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100300     GAZP      1  20210701  282.42  282.86  282.32   282.74  487660
# 100400     GAZP      1  20210701  282.74  283.00  282.50   282.77  416910
# 100500     GAZP      1  20210701  282.64  282.90  282.50   282.59  264160
# 100600     GAZP      1  20210701  282.67  282.69  282.11   282.25  337050
# ...         ...    ...       ...     ...     ...     ...      ...     ...
# 155100     GAZP      1  20210713  293.35  293.47  293.31   293.40   20460
# 155200     GAZP      1  20210713  293.40  293.41  293.22   293.33  200960
# 155300     GAZP      1  20210713  293.30  293.35  293.22   293.35   24000
# 155400     GAZP      1  20210713  293.35  293.42  293.28   293.31   91710
# 155500     GAZP      1  20210713  293.25  293.28  293.25   293.28    3960
#
# [6842 rows x 8 columns]

# %%
df_c = df.join(df2, on="<TIME>", rsuffix="_s")
df_c[0:20]
# Out:
#        <TICKER>  <PER>    <DATE>  <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>  \
# <TIME>
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100200     GAZP      1  20210701  281.88  282.57  281.88   282.47  438510
# 100300     GAZP      1  20210701  282.42  282.86  282.32   282.74  487660
# 100300     GAZP      1  20210701  282.42  282.86  282.32   282.74  487660
# 100300     GAZP      1  20210701  282.42  282.86  282.32   282.74  487660
# ...
