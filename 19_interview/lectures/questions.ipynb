# %% [markdown]
# # Собеседование на должность Data Scientist

# %% [markdown]
# [109 популярных вопросов на собеседовании в сфере Data science](https://amazinghiring.ru/blog/2017/10/23/109-%D0%BF%D0%BE%D0%BF%D1%83%D0%BB%D1%8F%D1%80%D0%BD%D1%8B%D1%85-%D0%B2%D0%BE%D0%BF%D1%80%D0%BE%D1%81%D0%BE%D0%B2-%D0%BD%D0%B0-%D1%81%D0%BE%D0%B1%D0%B5%D1%81%D0%B5%D0%B4%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8/)
#
# [40 вопросов по статистике с собеседований на должность Data Scientist](https://proglib.io/p/40-voprosov-po-statistike-s-sobesedovaniya-na-dolzhnost-data-scientist-2020-09-24)
#
# [Вопросы для собеседования с Data scientist](https://itanddigital.ru/interviewdatascientist)

# %% [markdown]
# **[Список вопросов/ответов с реальных собеседований](https://docs.google.com/spreadsheets/d/17FRX9MeAHThLDSlJSuXPlrnNnNE4vTnjZSV7CWmGj9k/edit?usp=sharing) со ссылками на вакансии.**

# %% [markdown]
# ## Общие рекомендации

# %% [markdown]
# ### Общение с HR
#
# Честность vs. Прагматизм

# %% [markdown]
# ### Как отвечать на вопрос "расскажите о себе"?

# %% [markdown]
# ### Эмоции
#
# - Нормально чувствовать какую-то тревогу перед собеседованием. Люди - не роботы.
# - "Синдром самозванца" - это не повод оставить попытки найти что-то хорошее, важно совершать адекватные шаги к цели несмотря на эмоции (они могут быть ложными, скорее всего ложные).
# - Ошибки на собеседовании - это повод записать все вопросы и найти на них ответы как можно скорее. Больше они ничего не значат, они не говорят о вас как о человеке и как о специалисте. Просто раньше вы с этим не сталкивались, сейчас сталкнулись и разбираетесь с этим.

# %% [markdown]
# ### О чем лучше не говорить?
#
# - Вопрос: "Вы проходите еще интервью? На каком этапе там?".
#     - Плохой ответ: "Да, везде все завалил, ничего не получается, вы уже 20-е к кому я пытаюсь устроиться...".
#     - Хороший ответ: "Да, есть несколько мест, все на разных этапах. Пока что ничего конкретно не могу сказать".
#
# - Вопрос: "Почему решили сменить работу?".
#     - Плохой ответ: "Там все ужасно, я со всеми поссорился", "Меня уволили, потому что я прокрастинировал", "Я там год ничего не делал и меня сократили".
#     - Хороший ответ: "Мне не нравилось количество совещаний", "Слишком много переработок", "Нет возможности развиваться".

# %% [markdown]
# ### О чем спросить у HR?
#
# - Оплата (есть ли "мотивационная часть" или все белое? ИП или трудовая?)
# - График работы (фиксированное начало/окончание дня, удаленка, отсутствие по болезни).
# - Сколько этапов собседования?
# - Какого типа вопросы будут на каждом этапе (life coding, case study, теоретические вопросы, много ли будет про разработку, алгоритмические задачи)?
# - Когда и где пришлют ссылку на онлайн собеседование?
# - При удаленно работе осуществляется ли какой-то контроль (таймеры, фото экрана, камера, сканирование приложений)?
# - Сколько людей ищут?
# - Почему ищут нового человека?

# %% [markdown]
# ### О чем спросить на техническом собеседовании?
#
# - Переработки оплачиваются?
# - Как часть бывают переработки?
# - Как выстроен процесс разработки (SCRAM? Сколько длятся спринты? Как часто и как долго проходят совещания?).
# - Насколько большое домашнее задание? Какие требования и рекомендации к выполнению?
# - Почему ищут нового человека?

# %% [markdown]
# ## Математика

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ## Теория DS

# %% [markdown]
# ### Что такое Data Science?
#
# [01_introduction](../../01_introduction/lectures/01_introduction.ipynb)
#
# Наука о данных - это междисциплинарная область, в которой используются научные методы, процессы, алгоритмы и системы для извлечения знаний и понимания из структурных и неструктурированных данных. Наука о данных объединяет концепции интеллектуального анализа данных, машинного обучения и больших данных.
#
# <img src="images/ds_cs_ms.png" width="600" height="600"/>

# %% [markdown]
# ### В чем отличие DS, ML, DL?
#
# [01_introduction](../../01_introduction/lectures/01_introduction.ipynb)
#
# <img src="images/ai_ml_dl_dnn.png" width="600" height="600"/>

# %% [markdown]
# ### В чем сходства и отличия между обучением с учителем и обучением без учителя?
#
# [01_learning_types](../../05_modeling_info_1/lectures/01_learning_types.ipynb)
#
# **Обучение с учителем** и **обучение без учителя** - это два метода машинного обучения, которые используются в разных сценариях и с разными наборами данных.
#
# **Различие** между этими двумя методами в том, что **обучение с учителем** - это метод машинного обучения, при котором модели обучаются с использованием **размеченных данных**.
#
# При **обучении с учителем** модели должны **найти функцию сопоставления для сопоставления входной переменной (`X`) с выходной переменной (`y`)**.
#
# **Обучение без учителя** - это еще один метод машинного обучения, в котором шаблоны выводятся из **неразмеченных входных данных**.
#
# Цель **обучения без учителя** - **найти структуру и закономерности** во входных данных.

# %% [markdown]
# ### Опишите этапы проекта в DS
#
# [01_introduction](../../01_introduction/lectures/01_introduction.ipynb)
#
# <img src="images/ds_pipeline_agile.png" alt="ds_pipeline_agile" width="1000" height="1000"/>
#
# - Понимание бизнес-проблемы.
# - Изучение данных и ознакомление с ними.
# - Подготовка данных к моделированию посредством обнаружения резко отклоняющихся значений (выбросов), преобразования переменных, обработки пропущенных значений и т. д.
# - Разработка модели и анализ результата для внесения соответствующих изменений или модификаций в модель (итеративный шаг, который повторяется до достижения наилучшего возможного результата).
# - Проверка модели с использованием нового набора данных (тестирование).
# - Внедрение модели и отслеживание результата для анализа качества.

# %% [markdown]
# ### Что такое выбросы и как с ними обращаться?
#
# [01_outliers](../../04_data_preparation/lectures/01_outliers.ipynb)
#
# Выбросы - это точки данных, которые не принадлежат определенной совокупности.
#
# Выброс - это ненормальное наблюдение, которое очень сильно отличается от других значений, принадлежащих набору.
#
# Идентификация выбросов значений может быть произведена с помощью графического анализа (`boxplot`, `hist`). Также можно использовать методы основанные на IQR и стандартном отклонении ($3\sigma$).
#
# Есть два популярных способа обработки выбросов:
# - Изменить значение так, чтобы его можно было привести в диапазон (например, найти ошибку и исправить ее).
# - Просто удалить значение.

# %% [markdown]
# ### Расскажите Deep Learning?
#
# [01_dl_info](../../14_modeling_dl_info/lectures/01_dl_info.ipynb)
#
# **Глубокое обучение** имеет широкий спектр применений, от фильтрации социальных сетей до анализа медицинских изображений и распознавания речи.
#
# Caffe, Chainer, Keras, Microsoft Cognitive Toolkit, Pytorch и TensorFlow - одни из самых популярных фреймворков глубокого обучения на сегодняшний день.
#
# Хотя глубокое обучение существует уже давно, только недавно оно получило всемирное признание, в связи с такими факторами как:
# - Увеличение объема генерации данных из различных источников.
# - Рост аппаратных ресурсов, необходимых для запуска моделей глубокого обучения.

# %% [markdown]
# ## Classic ML

# %% [markdown]
# ### Что такое линейная регрессия?
#
# [03_simple_linear](../../06_modeling_ml_regression_1/lectures/03_simple_linear.ipynb)
#
# Линейная регрессия **помогает понять линейную связь между зависимыми (`y`) и независимыми переменными (`X`)**. Линейная регрессия - это алгоритм обучения с учителем, который помогает установить линейную связь между двумя переменными.
#
# Один из них является предиктором или независимой переменной (`X`), а другой - ответом или зависимой переменной (`y`).
#
# Линейная регрессия направлена на понимание того, как зависимая переменная (`y`) изменяется по отношению к независимой переменной (`X`).
#
# Если есть только одна независимая переменная, то это называется простой линейной регрессией, а если существует более одной независимой переменной, то это называется множественной линейной регрессией.

# %% [markdown]
# ### Расскажите про алгоритм машинного обучения SVM.
#
# [05_svm_classifier](../../07_modeling_ml_classification_1/lectures/05_svm_classifier.ipynb)
#
# SVM = Метод опорных векторов — набор схожих алгоритмов обучения с учителем, использующихся для задач классификации и регрессионного анализа.
#
# SVM использует гиперплоскости для разделения разных классов на основе предоставленной функции ядра.

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ## DL

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ## Вопросы-рассуждения

# %% [markdown]
# ### Модель, построенная вашей командой, обеспечивает точность 90%. Что нужно знать, чтобы понять, хорошо это или нет?

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
# ###
