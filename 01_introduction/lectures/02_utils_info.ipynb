# %% [markdown]
# ---
#
# **Источники:**
#
# [Writing Math Equations in Jupyter Notebook: A Naive Introduction](https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214)
#
# [Что есть в новом JupyterLab для пользователей?](https://habr.com/ru/company/otus/blog/351820/#:~:text=JupyterLab%20%E2%80%94%20%D1%8D%D1%82%D0%BE%20%D0%B8%D0%BD%D1%82%D0%B5%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%B0%D1%8F%20%D1%81%D1%80%D0%B5%D0%B4%D0%B0%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B8,%D1%81%20%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0%D0%BC%D0%B8%2C%20%D0%BA%D0%BE%D0%B4%D0%BE%D0%BC%20%D0%B8%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.&text=%D0%9F%D1%80%D0%BE%D0%B5%D0%BA%D1%82%20Jupyter%20%D1%81%D1%83%D1%89%D0%B5%D1%81%D1%82%D0%B2%D1%83%D0%B5%D1%82%20%D0%B4%D0%BB%D1%8F%20%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B8,%D0%B4%D0%BB%D1%8F%20%D0%B8%D0%BD%D1%82%D0%B5%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D1%8B%D1%85%20%D0%B8%20%D0%B2%D0%BE%D1%81%D0%BF%D1%80%D0%BE%D0%B8%D0%B7%D0%B2%D0%BE%D0%B4%D0%B8%D0%BC%D1%8B%D1%85%20%D0%B2%D1%8B%D1%87%D0%B8%D1%81%D0%BB%D0%B5%D0%BD%D0%B8%D0%B9.)
#
# [Магия Jupyter Notebook](https://tirinox.ru/jupyter-notebook-magic/)
#
#
# ---

# %% [markdown]
# # [Jupyter](https://jupyter.org/)

# %% [markdown]
# - **Jupyter Notebook** позволяет пользователям создавать и обмениваться документами, которые объединяют живой код с нарративным текстом, математическими уравнениями, визуализацией, интерактивными элементами управления и многими другими прекрасными фичами.
# - **Jupyter Notebook** также предоставляет строительные блоки для интерактивных вычислений с данными: файловый браузер, терминалы и текстовый редактор.
#
# - С 2011 года **Jupyter Notebook** является флагманским проектом по созданию воспроизводимых вычислительных описаний.
#
# - **JupyterLab** — это интерактивная среда разработки для работы с блокнотами, кодом и данными.
#
# - Самое главное, что **JupyterLab** имеет полную поддержку блокнотов Jupyter.
#
# - Кроме того, **JupyterLab** позволяет использовать текстовые редакторы, терминалы, средства просмотра файлов данных и другие настраиваемые компоненты рядом с блокнотами в разбитой на вкладки рабочей области.
#
# - **JupyterLab** позволяет организовать рабочую зону с помощью блокнотов, текстовых файлов, терминалов и выводов блокнотов.

# %% [markdown]
# ## Работа с терминалом из `Jupyter`

# %% [markdown]
# ---
#
# **ВНИМАНИЕ!**
#
# Необходимо установить пакет `nb_conda_kernels`
#
# <img src="images/nb_conda_kernels.png" alt="nb_conda_kernels"/>
#
#
# Выбрать в JupyterLab правильную среду
#
# <img src="images/jupyter_env.png" alt="jupyter_env"/>

# %% [markdown]
# **ИЛИ**

# %%
# !conda install -c conda-forge nb_conda_kernels -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/LevelUp_DataScience_Py_R
#
#   added / updated specs:
#     - nb_conda_kernels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nb_conda_kernels-2.3.1     |   py38h578d9bd_0          27 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          31 KB
#
# The following NEW packages will be INSTALLED:
#
#   nb_conda_kernels   conda-forge/linux-64::nb_conda_kernels-2.3.1-py38h578d9bd_0
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %% [markdown]
# **ИЛИ**

# %% [markdown]
# В терминале PyCharm:
# ```
# conda install -c conda-forge nb_conda_kernels -y
# ```

# %% [markdown]
# После этого обязательно перезапустить Jupyter-lab (File-Shut Down)
#
# ---

# %% [markdown]
# Можно вызывать системные команды прямо из блокнота через знак восклицания (!)

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /home/ira/anaconda3
# LevelUp_DataScience   *  /home/ira/anaconda3/envs/LevelUp_DataScience
# LevelUp_Python1          /home/ira/anaconda3/envs/LevelUp_Python1
# LevelUp_Python2          /home/ira/anaconda3/envs/LevelUp_Python2

# %% [markdown]
# ИЛИ

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /home/ira/anaconda3
# LevelUp_DataScience   *  /home/ira/anaconda3/envs/LevelUp_DataScience
# LevelUp_Python1          /home/ira/anaconda3/envs/LevelUp_Python1
# LevelUp_Python2          /home/ira/anaconda3/envs/LevelUp_Python2

# %%
# Для MacOS/Ubuntu
# !which pip

# Для Windows
# !where pip
# Out:
# pip 20.3.3 from /home/ira/anaconda3/envs/LevelUp_DataScience/lib/python3.8/site-packages/pip (python 3.8)

# %%
# Установить необходимые пакеты

# !conda install pandas numpy matplotlib -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# alabaster                         0.7.12
# anyio                             2.1.0
# AnyQt                             0.0.10
# appdirs                           1.4.4
# argh                              0.26.2
# argon2-cffi                       20.1.0
# astroid                           2.4.2
# astropy                           4.2
# async-generator                   1.10
# atomicwrites                      1.4.0
# attrs                             20.3.0
# Automat                           20.2.0
# autopep8                          1.5.5
# Babel                             2.9.0
# backcall                          0.2.0
# baycomp                           1.0.2
# bcrypt                            3.2.0
# black                             19.10b0
# bleach                            3.3.0
# bokeh                             2.2.3
# Bottleneck                        1.3.2
# ...

# %%
# !pwd
# Out:
# /home/ira/LevelUp/data-science-course-original/01_introduction/lectures

# %%
# rm = remove (удалить)

# !rm images/cat.jpg

# %%
# ls = list directory contents
# l = long listing format
# a = do not ignore entries starting with .

# !ls -la
# Out:
# total 224
# drwxrwxr-x 4 ira ira   4096 мар 12 18:43 .
# drwxrwxr-x 4 ira ira   4096 фев 16 19:46 ..
# -rw-rw-r-- 1 ira ira   4040 фев 17 15:51 00_about.ipynb
# -rw-rw-r-- 1 ira ira  11121 мар 12 18:43 01_introduction.ipynb
# -rw-rw-r-- 1 ira ira 194058 мар 12 13:43 02_utils_info.ipynb
# drwxrwxr-x 2 ira ira   4096 мар 12 18:43 images
# drwxrwxr-x 2 ira ira   4096 мар 12 18:42 .ipynb_checkpoints

# %%
# ls = list directory contents
# l = long listing format
# a = do not ignore entries starting with .

# !ls images -la
# Out:
# total 1960
# drwxrwxr-x 2 ira ira   4096 мар 12 18:43 .
# drwxrwxr-x 4 ira ira   4096 мар 12 18:43 ..
# -rw-rw-r-- 1 ira ira 238198 фев 16 17:23 ai_ml_dl_dnn.png
# -rw-rw-r-- 1 ira ira  62597 фев 16 17:23 ai_pipeline_people.jpg
# -rw-rw-r-- 1 ira ira 249040 фев 16 17:23 ai_pipeline_real.png
# -rw-rw-r-- 1 ira ira  76303 фев 16 17:23 ai_roles.png
# -rw-rw-r-- 1 ira ira  28188 фев 16 17:23 ds_cs_ms.png
# -rw-rw-r-- 1 ira ira 242531 фев 16 17:23 ds_lifecycle.png
# -rw-rw-r-- 1 ira ira 185678 фев 16 17:23 ds_pipeline_agile.png
# -rw-rw-r-- 1 ira ira   5611 фев 16 17:23 jupyter_env.png
# -rw-rw-r-- 1 ira ira   5732 фев 16 17:23 nb_conda_kernels.png
# -rw-rw-r-- 1 ira ira 882782 фев 16 17:23 ryndovaira.jpg

# %%
# Скачать файл (картинку с котиком)

# !wget -O images/cat.jpg https://bugaga.ru/uploads/posts/2018-07/1532363814_koshki-vampiry-3.jpg
# Out:
# --2021-03-12 18:43:32--  https://bugaga.ru/uploads/posts/2018-07/1532363814_koshki-vampiry-3.jpg
# Resolving bugaga.ru (bugaga.ru)... 88.99.4.81
# Connecting to bugaga.ru (bugaga.ru)|88.99.4.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58794 (57K) [image/jpeg]
# Saving to: ‘images/cat.jpg’
#
# images/cat.jpg      100%[===================>]  57,42K  --.-KB/s    in 0,05s
#
# 2021-03-12 18:43:32 (1,20 MB/s) - ‘images/cat.jpg’ saved [58794/58794]

# %%
# ls = list directory contents
# l = long listing format
# a = do not ignore entries starting with .

# !ls images -la
# Out:
# total 2020
# drwxrwxr-x 2 ira ira   4096 мар 12 18:43 .
# drwxrwxr-x 4 ira ira   4096 мар 12 18:43 ..
# -rw-rw-r-- 1 ira ira 238198 фев 16 17:23 ai_ml_dl_dnn.png
# -rw-rw-r-- 1 ira ira  62597 фев 16 17:23 ai_pipeline_people.jpg
# -rw-rw-r-- 1 ira ira 249040 фев 16 17:23 ai_pipeline_real.png
# -rw-rw-r-- 1 ira ira  76303 фев 16 17:23 ai_roles.png
# -rw-rw-r-- 1 ira ira  58794 июл 23  2018 cat.jpg
# -rw-rw-r-- 1 ira ira  28188 фев 16 17:23 ds_cs_ms.png
# -rw-rw-r-- 1 ira ira 242531 фев 16 17:23 ds_lifecycle.png
# -rw-rw-r-- 1 ira ira 185678 фев 16 17:23 ds_pipeline_agile.png
# -rw-rw-r-- 1 ira ira   5611 фев 16 17:23 jupyter_env.png
# -rw-rw-r-- 1 ira ira   5732 фев 16 17:23 nb_conda_kernels.png
# -rw-rw-r-- 1 ira ira 882782 фев 16 17:23 ryndovaira.jpg

# %% [markdown]
# <img src="images/cat.jpg" alt="cat" width="300" height="300"/>

# %% [markdown]
# ## Магия jupyter

# %% [markdown]
# **%magic** — выведет документацию по всем-всем доступным магическим функциям.

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %% [markdown]
# **%lsmagic** — просто список этих функций.

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# **%timeit** – измеряет среднее время выполнения кусочка кода, при этом вывод гораздо более информативен, чем обычный вызов timeit.timeit; и не требует лишних import.

# %%
def test():
  return sum(range(100))
# %timeit test()
# Out:
# 1.1 µs ± 7.59 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# **%%timeit** – многострочный вариант предыдущей функции.

# %%
# %%timeit
x = 10
x += 20
x /= 2
# Out:
# 63.6 ns ± 0.0637 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# **%pinfo [имя] или [имя]?** – покажет документацию по функции или классу [имя].

# %%
import numpy as np
# %pinfo np.random.uniform
# Out:
# Docstring:
# uniform(low=0.0, high=1.0, size=None)
#
# Draw samples from a uniform distribution.
#
# Samples are uniformly distributed over the half-open interval
# ``[low, high)`` (includes low, but excludes high).  In other words,
# any value within the given interval is equally likely to be drawn
# by `uniform`.
#
# .. note::
#     New code should use the ``uniform`` method of a ``default_rng()``
#     instance instead; please see the :ref:`random-quick-start`.
#
# Parameters
# ----------
# low : float or array_like of floats, optional
#     Lower boundary of the output interval.  All values generated will be
#     greater than or equal to low.  The default value is 0.
# high : float or array_like of floats
#     Upper boundary of the output interval.  All values generated will be
#     less than or equal to high.  The default value is 1.0.
# size : int or tuple of ints, optional
#     Output shape.  If the given shape is, e.g., ``(m, n, k)``, then
# ...

# %% [markdown]
# Или

# %%
import numpy as np
np.random.uniform?
# Out:
# Docstring:
# uniform(low=0.0, high=1.0, size=None)
#
# Draw samples from a uniform distribution.
#
# Samples are uniformly distributed over the half-open interval
# ``[low, high)`` (includes low, but excludes high).  In other words,
# any value within the given interval is equally likely to be drawn
# by `uniform`.
#
# .. note::
#     New code should use the ``uniform`` method of a ``default_rng()``
#     instance instead; please see the :ref:`random-quick-start`.
#
# Parameters
# ----------
# low : float or array_like of floats, optional
#     Lower boundary of the output interval.  All values generated will be
#     greater than or equal to low.  The default value is 0.
# high : float or array_like of floats
#     Upper boundary of the output interval.  All values generated will be
#     less than or equal to high.  The default value is 1.0.
# size : int or tuple of ints, optional
#     Output shape.  If the given shape is, e.g., ``(m, n, k)``, then
# ...

# %% [markdown]
# **%matplotlib inline** - указывает, что график необходимо построить все в той же оболочке Jupyter, но теперь он выводится как обычная картинка. Данный способ удобен тем, что позволяет проводить очень много экспериментов в рамках одного окна.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# # Как искать информацию в интернете

# %% [markdown]
# - Использовать английский язык.
#
# - Освоить специальные символы (`"`, `+`, `-`, ...). Можно прочитать подробнее в статье [Как правильно искать в Google](https://habr.com/ru/sandbox/46956/) или в любой аналогичной.

# %% [markdown]
# # Table of Contents (TOC)

# %%
# https://anaconda.org/conda-forge/nodejs
# !conda install -c conda-forge nodejs -y
# !conda install -c conda-forge/label/gcc7 nodejs -y
# !conda install -c conda-forge/label/cf201901 nodejs -y
# !conda install -c conda-forge/label/cf202003 nodejs -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/LevelUp_DataScience
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nodejs-6.13.1              |                0        11.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   nodejs             conda-forge/linux-64::nodejs-6.13.1-0
#
#
#
# ...
# nodejs-6.13.1        | 11.9 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/LevelUp_DataScience
#
#   added / updated specs:
#     - nodejs
#
#
# ...

# %%
# !conda install tornado -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/LevelUp_DataScience
#
#   added / updated specs:
#     - tornado
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/label/cf202003::ca-certif~ --> pkgs/main::ca-certificates-2021.5.25-h06a4308_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2021.5.30-py38h5~ --> pkgs/main::certifi-2020.12.5-py38h06a4308_0
#   openssl            conda-forge::openssl-1.1.1k-h7f98852_0 --> pkgs/main::openssl-1.1.1k-h27cfd23_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -c conda-forge jupyter_contrib_nbextensions -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ira/anaconda3/envs/LevelUp_DataScience
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyter_contrib_core-0.3.3 |             py_2          15 KB  conda-forge
#     jupyter_latex_envs-1.4.6   |  pyhd8ed1ab_1002         735 KB  conda-forge
#     lxml-4.6.3                 |   py38hf1fe3a4_0         1.6 MB  conda-forge
#     pyyaml-5.4.1               |   py38h497a2fe_0         192 KB  conda-forge
#     yaml-0.2.5                 |       h516909a_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.6 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda update conda --yes
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /home/ira/anaconda3/envs/LevelUp_DataScience
#   package name: conda

# %%
# https://github.com/jupyterlab/jupyterlab-toc
# !jupyter labextension install @jupyterlab/toc
# Out:
# Config option `kernel_spec_manager_class` not recognized by `InstallLabExtensionApp`.
# Building jupyterlab assets (build:prod:minimize)

# %% [markdown]
# # Автодополнение (Autocompletion)
#
# [Kite Autocomplete Extension for JupyterLab](https://github.com/kiteco/jupyterlab-kite#installing-the-kite-extension-for-jupyterlab)
